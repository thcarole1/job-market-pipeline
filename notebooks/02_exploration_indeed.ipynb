# %% [markdown]
# # 02_exploration_indeed

# %% [markdown]
# Cloudflare résiste — **Indeed** est fortement protégé
# **Security Check** est un niveau de protection encore plus élevé que **Just a moment**. <br>
# Indeed **bloque activement les scrapers automatisés**, **même sophistiqués**.<br>
#
# __La réalité en 2026__<br>
# Indeed a considérablement durci sa protection. <br>
# Contourner Cloudflare de manière fiable **nécessite des outils payants** (proxies rotatifs, navigateurs anti-détection) qui ne sont pas adaptés à un projet de formation.<br>
# La solution la plus sage : **changer de source**.

# %% [markdown]
# **Sources alternatives** accessibles pour votre projet :
# - **Option 1** — **Welcome to the Jungle** (recommandé) => Site français, peu protégé, riche en offres tech : await page.goto("https://www.welcometothejungle.com/fr/jobs?refinementList%5Boffice_country_codes%5D%5B%5D=FR&query=data+engineer")
# - **Option 2** — **APEC** => Site institutionnel français, aucune protection anti-scraping : await page.goto("https://www.apec.fr/candidat/recherche-emploi.html/emploi?motsCles=data+engineer&lieu=75")
# - **Option 3** — **Hellowork** => await page.goto("https://www.hellowork.com/fr-fr/emploi/recherche.html?k=data+engineer&l=Paris")

# %% [markdown]
# ## Choix Option 1 : Welcome to the jungle

# %%
from pprint import pprint
import json
from rich.tree import Tree
from rich import print as rprint

# %%
def json_vers_arbre(data, arbre, prefixe=""):
    """
    Construit récursivement un arbre Rich
    à partir d'un dictionnaire JSON.
    """
    if isinstance(data, dict):
        for cle, valeur in data.items():
            if isinstance(valeur, dict):
                # Sous-dictionnaire → nouveau nœud
                noeud = arbre.add(f"[bold cyan]{cle}[/] 📁")
                json_vers_arbre(valeur, noeud)

            elif isinstance(valeur, list):
                # Tableau → nouveau nœud avec indication du type
                noeud = arbre.add(f"[bold yellow]{cle}[/] 📋 [dim]({len(valeur)} éléments)[/]")
                if valeur and isinstance(valeur[0], dict):
                    json_vers_arbre(valeur[0], noeud)

            else:
                # Valeur simple → feuille
                type_valeur = type(valeur).__name__
                arbre.add(f"[green]{cle}[/] [dim]({type_valeur})[/]")


def afficher_structure_json(data, titre="Structure JSON"):
    """
    Affiche la structure d'un JSON sous forme d'arbre visuel.
    """
    arbre = Tree(f"[bold magenta]{titre}[/]")
    json_vers_arbre(data, arbre)
    rprint(arbre)

# %%
from playwright.async_api import async_playwright

'''Ce script simule un vrai navigateur Chrome pour accéder au site Welcome to the Jungle, 
puis interroge directement le moteur de recherche interne du site (Algolia) pour récupérer
les offres d'emploi Data Engineer en France. L'astuce centrale est d'utiliser le navigateur 
comme intermédiaire de confiance — Algolia refuse les requêtes venant d'un script Python externe, 
mais accepte celles venant d'un navigateur sur le domaine de WTTJ. Le script récupère les offres
page par page et les accumule dans une liste.'''

# Fonction principale — nb_pages contrôle combien de pages on récupère
# (20 offres par page, donc nb_pages=3 → 60 offres maximum)
async def scraper_wttj(nb_pages=3):

    # Liste qui accumulera toutes les offres récupérées
    toutes_offres = []

    # Démarrage de Playwright — le gestionnaire de navigateur
    async with async_playwright() as p:

        # Lancement d'un navigateur Chromium
        # headless=True → pas de fenêtre visible (mode silencieux)
        # disable-blink-features=AutomationControlled → masque le fait
        # que Chrome est piloté par un script (contourne certaines détections)
        browser = await p.chromium.launch(
            headless=True,
            args=["--disable-blink-features=AutomationControlled"]
        )

        # Création d'un contexte de navigation — comme un profil de navigateur
        # user_agent → on se fait passer pour un vrai Chrome sur Windows
        # viewport  → résolution d'écran standard d'un vrai utilisateur
        # locale    → langue française pour recevoir le bon contenu
        context = await browser.new_context(
            user_agent=(
                "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                "AppleWebKit/537.36 (KHTML, like Gecko) "
                "Chrome/120.0.0.0 Safari/537.36"
            ),
            viewport={"width": 1920, "height": 1080},
            locale="fr-FR",
        )

        # Injection d'un script JavaScript exécuté avant chaque page
        # navigator.webdriver est une propriété que les sites utilisent
        # pour détecter les navigateurs automatisés — on la masque
        # en lui faisant retourner "undefined" au lieu de "true"
        await context.add_init_script("""
            Object.defineProperty(navigator, 'webdriver', {
                get: () => undefined
            });
        """)

        # Ouverture d'un nouvel onglet dans le contexte créé
        page = await context.new_page()

        # Navigation vers la page de recherche WTTJ
        # wait_until="domcontentloaded" → on attend que le HTML de base
        # soit chargé, sans attendre tous les appels réseau
        # (networkidle bloquerait indéfiniment sur ce site)
        await page.goto(
            "https://www.welcometothejungle.com/fr/jobs?"
            "refinementList%5Boffice_country_codes%5D%5B%5D=FR"
            "&query=data+engineer",
            wait_until="domcontentloaded"
        )

        # Pause de 2 secondes pour laisser le JavaScript s'initialiser
        # et établir la session avec Algolia
        await page.wait_for_timeout(2000)

        # Boucle sur chaque page de résultats
        for numero_page in range(nb_pages):
            print(f"Page {numero_page + 1}/{nb_pages}...")

            # Exécution d'un appel fetch() directement dans le navigateur
            # C'est la clé du fonctionnement : on appelle l'API Algolia
            # DEPUIS le navigateur qui est sur le domaine WTTJ
            # → Algolia accepte la requête car elle vient du bon domaine
            # f""" ... """ permet d'injecter la variable Python numero_page
            # dans le code JavaScript avec {numero_page}
            resultats = await page.evaluate(f"""
                async () => {{
                    const response = await fetch(
                        "https://CSEKHVMS53-dsn.algolia.net/1/indexes/wttj_jobs_production_fr/query",
                        {{
                            method: "POST",
                            headers: {{
                                // Identifiant de l'application Algolia de WTTJ
                                "X-Algolia-Application-Id": "CSEKHVMS53",
                                // Clé publique extraite des requêtes du navigateur
                                "X-Algolia-API-Key": "4bd8f6215d0cc52b26430765769e65a0",
                                "Content-Type": "application/json"
                            }},
                            body: JSON.stringify({{
                                query: "data engineer",  // mots recherchés
                                hitsPerPage: 20,         // 20 offres par page
                                page: {numero_page}      // numéro de page (0, 1, 2...)
                            }})
                        }}
                    );
                    // Conversion de la réponse HTTP en objet JSON Python
                    return await response.json();
                }}
            """)

            # Extraction des offres (hits) et du nombre total depuis la réponse
            hits    = resultats.get("hits", [])     # liste des offres de cette page
            nb_hits = resultats.get("nbHits", 0)    # nombre total d'offres disponibles

            print(f"  → {len(hits)} hits, {nb_hits} total")

            # Ajout des offres de cette page à la liste globale
            toutes_offres.extend(hits)

            # Pause de 0.5 seconde entre chaque requête
            # pour ne pas surcharger le serveur et éviter la détection
            await page.wait_for_timeout(500)

        # Fermeture du navigateur — libération des ressources
        await browser.close()

    # Retourne la liste complète de toutes les offres récupérées
    return toutes_offres

# %%
if __name__ == "__main__":
    
    offres = await scraper_wttj(nb_pages=1)
    print("offres ok")

    print(f"\n✅ {len(offres)} offres récupérées")
    print("Nombre offres ok")

    if offres:
        print("\nClés disponibles :")
        print(list(offres[0].keys()))
    print("Clés offres ok")

    # Afficher 
    afficher_structure_json(offres[0], "Offre Welcome to the Jungle")
    pprint(offres[0])
    print("FIN")
# Out:
# Page 1/1...
#   → 20 hits, 1666 total
# offres ok
#
# ✅ 20 offres récupérées
# Nombre offres ok
#
# Clés disponibles :
# ['profile_ranking', 'is_boosted', 'summary', 'published_at_timestamp', 'has_remote', 'salary_minimum', 'salary_period', 'has_salary_yearly_minimum', 'salary_maximum', 'education_level', 'wk_reference', 'organization_score', 'source_stage', 'salary_currency', 'has_education_level', 'experience_level_minimum', 'rank_group_1', 'contract_duration_maximum', '_geoloc', 'sectors', 'benefits', 'remote', 'organization', 'rank_group_2', 'offices', 'slug', 'has_benefits', 'reference', 'published_at', 'language', 'profile', 'rank_group_3', 'salary_yearly_minimum', 'name', 'has_contract_duration', 'key_missions', 'published_at_date', 'contract_duration_minimum', 'has_experience_level_minimum', 'new_profession', 'contract_type', 'objectID', '_highlightResult']
# Clés offres ok
# Offre Welcome to the Jungle
# ├── profile_ranking (int)
# ├── is_boosted (bool)
# ├── summary (str)
# ├── published_at_timestamp (int)
# ├── has_remote (bool)
# ├── salary_minimum (NoneType)
# ├── salary_period (str)
# ├── has_salary_yearly_minimum (bool)
# ├── salary_maximum (NoneType)
# ├── education_level (str)
# ├── wk_reference (str)
# ├── organization_score (int)
# ├── source_stage (str)
# ├── salary_currency (str)
# ├── has_education_level (bool)
# ├── experience_level_minimum (int)
# ├── rank_group_1 (int)
# ├── contract_duration_maximum (NoneType)
# ├── _geoloc 📋 (1 éléments)
# │   ├── lat (float)
# │   └── lng (float)
# ├── sectors 📋 (2 éléments)
# │   ├── name (str)
# │   ├── reference (str)
# │   ├── parent_name (str)
# │   └── parent_reference (str)
# ├── benefits 📋 (33 éléments)
# ├── remote (str)
# ├── organization 📁
# │   ├── name (str)
# │   ├── description (NoneType)
# │   ├── reference (str)
# │   ├── labels 📋 (0 éléments)
# │   ├── summary (str)
# │   ├── profile_type (str)
# │   ├── slug (str)
# │   ├── logo 📁
# │   │   ├── url (str)
# │   │   └── thumb 📁
# │   │       └── url (str)
# │   ├── nb_employees (int)
# │   ├── creation_year (int)
# │   ├── cover_image 📁
# │   │   ├── small 📁
# │   │   │   └── url (str)
# │   │   ├── url (str)
# │   │   ├── medium 📁
# │   │   │   └── url (str)
# │   │   ├── large 📁
# │   │   │   └── url (str)
# │   │   └── social 📁
# │   │       └── url (str)
# │   ├── commitments 📋 (0 éléments)
# │   ├── equality_index (int)
# │   └── profile_ranking (int)
# ├── rank_group_2 (int)
# ├── offices 📋 (1 éléments)
# │   ├── state (str)
# │   ├── city (str)
# │   ├── country (str)
# │   ├── country_code (str)
# │   ├── district (str)
# │   ├── local_district (str)
# │   ├── local_city (str)
# │   └── local_state (str)
# ├── slug (str)
# ├── has_benefits (bool)
# ├── reference (str)
# ├── published_at (str)
# ├── language (str)
# ├── profile (str)
# ├── rank_group_3 (int)
# ├── salary_yearly_minimum (NoneType)
# ├── name (str)
# ├── has_contract_duration (bool)
# ├── key_missions 📋 (3 éléments)
# ├── published_at_date (str)
# ├── contract_duration_minimum (NoneType)
# ├── has_experience_level_minimum (bool)
# ├── new_profession 📁
# │   ├── sub_category_reference (str)
# │   ├── sub_category_name (str)
# │   ├── category_reference (str)
# │   ├── category_name (str)
# │   ├── pivot_name (str)
# │   └── pivot_reference (str)
# ├── contract_type (str)
# ├── objectID (str)
# └── _highlightResult 📁
#     ├── summary 📁
#     │   ├── value (str)
#     │   ├── matchLevel (str)
#     │   ├── fullyHighlighted (bool)
#     │   └── matchedWords 📋 (2 éléments)
#     ├── organization 📁
#     │   └── name 📁
#     │       ├── value (str)
#     │       ├── matchLevel (str)
#     │       └── matchedWords 📋 (0 éléments)
#     ├── offices 📋 (1 éléments)
#     │   ├── state 📁
#     │   │   ├── value (str)
#     │   │   ├── matchLevel (str)
#     │   │   └── matchedWords 📋 (0 éléments)
#     │   ├── city 📁
#     │   │   ├── value (str)
#     │   │   ├── matchLevel (str)
#     │   │   └── matchedWords 📋 (0 éléments)
#     │   ├── country 📁
#     │   │   ├── value (str)
#     │   │   ├── matchLevel (str)
#     │   │   └── matchedWords 📋 (0 éléments)
#     │   ├── country_code 📁
#     │   │   ├── value (str)
#     │   │   ├── matchLevel (str)
#     │   │   └── matchedWords 📋 (0 éléments)
#     │   ├── district 📁
#     │   │   ├── value (str)
#     │   │   ├── matchLevel (str)
#     │   │   └── matchedWords 📋 (0 éléments)
#     │   ├── local_district 📁
#     │   │   ├── value (str)
#     │   │   ├── matchLevel (str)
#     │   │   └── matchedWords 📋 (0 éléments)
#     │   ├── local_city 📁
#     │   │   ├── value (str)
#     │   │   ├── matchLevel (str)
#     │   │   └── matchedWords 📋 (0 éléments)
#     │   └── local_state 📁
#     │       ├── value (str)
#     │       ├── matchLevel (str)
#     │       └── matchedWords 📋 (0 éléments)
#     ├── profile 📁
#     │   ├── value (str)
#     │   ├── matchLevel (str)
#     │   ├── fullyHighlighted (bool)
#     │   └── matchedWords 📋 (1 éléments)
#     ├── name 📁
#     │   ├── value (str)
#     │   ├── matchLevel (str)
#     │   ├── fullyHighlighted (bool)
#     │   └── matchedWords 📋 (1 éléments)
#     └── new_profession 📁
#         ├── sub_category_reference 📁
#         │   ├── value (str)
#         │   ├── matchLevel (str)
#         │   ├── fullyHighlighted (bool)
#         │   └── matchedWords 📋 (1 éléments)
#         ├── sub_category_name 📁
#         │   ├── value (str)
#         │   ├── matchLevel (str)
#         │   └── matchedWords 📋 (0 éléments)
#         ├── category_name 📁
#         │   ├── value (str)
#         │   ├── matchLevel (str)
#         │   └── matchedWords 📋 (0 éléments)
#         ├── pivot_name 📁
#         │   ├── value (str)
#         │   ├── matchLevel (str)
#         │   └── matchedWords 📋 (0 éléments)
#         └── pivot_reference 📁
#             ├── value (str)
#             ├── matchLevel (str)
#             ├── fullyHighlighted (bool)
#             └── matchedWords 📋 (2 éléments)
# {'_geoloc': [{'lat': 48.82163, 'lng': 2.4135}],
#  '_highlightResult': {'name': {'fullyHighlighted': False,
#                                'matchLevel': 'partial',
#                                'matchedWords': ['engineer'],
#                                'value': '[Alternance] Analytics '
#                                         '<em>Engineer</em> F/H'},
#                       'new_profession': {'category_name': {'matchLevel': 'none',
#                                                            'matchedWords': [],
#                                                            'value': 'Technologie '
#                                                                     'et '
#                                                                     'ingénierie'},
#                                          'pivot_name': {'matchLevel': 'none',
#                                                         'matchedWords': [],
#                                                         'value': 'Ingénieur de '
#                                                                  'données'},
#                                          'pivot_reference': {'fullyHighlighted': False,
#                                                              'matchLevel': 'full',
#                                                              'matchedWords': ['data',
#                                                                               'engineer'],
#                                                              'value': '<em>data</em>-<em>engineer</em>-wOTA3'},
#                                          'sub_category_name': {'matchLevel': 'none',
#                                                                'matchedWords': [],
#                                                                'value': 'Données/Business '
#                                                                         'Intelligence'},
#                                          'sub_category_reference': {'fullyHighlighted': False,
#                                                                     'matchLevel': 'partial',
#                                                                     'matchedWords': ['data'],
#                                                                     'value': '<em>data</em>-business-intelligence-yZjY1'}},
#                       'offices': [{'city': {'matchLevel': 'none',
#                                             'matchedWords': [],
#                                             'value': 'Charenton-le-Pont'},
#                                    'country': {'matchLevel': 'none',
#                                                'matchedWords': [],
#                                                'value': 'France'},
#                                    'country_code': {'matchLevel': 'none',
#                                                     'matchedWords': [],
#                                                     'value': 'FR'},
#                                    'district': {'matchLevel': 'none',
#                                                 'matchedWords': [],
#                                                 'value': 'Val-de-Marne'},
#                                    'local_city': {'matchLevel': 'none',
#                                                   'matchedWords': [],
#                                                   'value': 'Charenton-le-Pont'},
#                                    'local_district': {'matchLevel': 'none',
#                                                       'matchedWords': [],
#                                                       'value': 'Val-de-Marne'},
#                                    'local_state': {'matchLevel': 'none',
#                                                    'matchedWords': [],
#                                                    'value': 'Île-de-France'},
#                                    'state': {'matchLevel': 'none',
#                                              'matchedWords': [],
#                                              'value': 'Ile-de-France'}}],
#                       'organization': {'name': {'matchLevel': 'none',
#                                                 'matchedWords': [],
#                                                 'value': 'Nickel'}},
#                       'profile': {'fullyHighlighted': False,
#                                   'matchLevel': 'partial',
#                                   'matchedWords': ['data'],
#                                   'value': '<p>🏅 A propos de vous</p>\r\n'
#                                            '<ul>\r\n'
#                                            '<li> Vous êtes étudiant de niveau '
#                                            "Bac+4 ou Bac+5 au sein d'une École "
#                                            "d'Ingénieurs / École de Commerce / "
#                                            'Université avec un parcours '
#                                            'orienté Digital / <em>Data</em> et '
#                                            'Business Analytics.</li>\r\n'
#                                            '<li> Vous souhaitez monter en '
#                                            'compétences sur les langages SQL '
#                                            'et Python.</li>\r\n'
#                                            '<li> Vous faites preuve de rigueur '
#                                            'et adaptabilité.</li>\r\n'
#                                            "<li> Vous disposez d'un bon esprit "
#                                            "d'équipe et d'une communication "
#                                            'efficace</li>\r\n'
#                                            "<li> Vous avez un niveau d'anglais "
#                                            'opérationnel vous permettant '
#                                            "d'échanger avec des équipes à "
#                                            "l'international</li>\r\n"
#                                            '</ul>\r\n'
#                                            '<p><br />🎁 Avantages</p>\r\n'
#                                            '<ul>\r\n'
#                                            '<li> Accord de télétravail '
#                                            '🏡</li>\r\n'
#                                            '<li> Parcours de carrière '
#                                            'dynamique</li>\r\n'
#                                            '<li> 25 jours de congés payés + 5 '
#                                            'Nickel days 🌴</li>\r\n'
#                                            '<li> Epargne salariale : accord de '
#                                            'participation et '
#                                            'abondement</li>\r\n'
#                                            '<li> La carte ticket restaurant '
#                                            '💳</li>\r\n'
#                                            '<li> Avantages collaborateurs BNP '
#                                            'Paribas : taux et tarifs '
#                                            'préférentiels</li>\r\n'
#                                            '<li> Mutuelle avantageuse Henner '
#                                            'et prévoyance</li>\r\n'
#                                            '<li> CSE (Chèques vacances, '
#                                            'activités extra-professionnelles, '
#                                            'etc)</li>\r\n'
#                                            '<li> Partenariat Gymlib pour les '
#                                            'activités sportives et de '
#                                            'bien-être</li>\r\n'
#                                            '<li> Localisation proche métro '
#                                            'Ligne 8 - Liberté à '
#                                            'Charenton</li>\r\n'
#                                            '<li> Pass Mobilité 🚲 500€ par an '
#                                            'pour financer vos dépenses en lien '
#                                            'avec la mobilité durable (sur vos '
#                                            'déplacement '
#                                            'domicile/travail)</li>\r\n'
#                                            '</ul>\r\n'
#                                            '<p><br />Le succès de Nickel, '
#                                            "c'est la diversité des profils et "
#                                            'la richesse des parcours de chacun '
#                                            "de nos collaborateurs. Plus qu'un "
#                                            "diplôme, c'est votre personnalité "
#                                            'et votre envie de nous rejoindre '
#                                            'qui fera la différence !</p>'},
#                       'summary': {'fullyHighlighted': False,
#                                   'matchLevel': 'full',
#                                   'matchedWords': ['data', 'engineer'],
#                                   'value': 'Rejoignez Nickel, une entreprise '
#                                            'innovante dans le secteur de la '
#                                            "fintech. En tant qu'Analytics "
#                                            '<em>Engineer</em> en alternance, '
#                                            'vous travaillerez au sein du Pôle '
#                                            '<em>Data</em>, où vous '
#                                            "contribuerez à l'amélioration de "
#                                            'la qualité et de la cohérence des '
#                                            'données. Vous développerez et '
#                                            'maintiendrez des pipelines de '
#                                            'données, élaborerez un système de '
#                                            'traçabilité des modèles et '
#                                            "contribuerez à la création d'un "
#                                            'socle de données optimal. Vous '
#                                            "bénéficierez d'un environnement de "
#                                            'travail dynamique avec de nombreux '
#                                            'avantages.'}},
#  'benefits': ['Entre 2-3 jours de télétravail',
#               'Salle d’allaitement',
#               'Salle de jeux',
#               'Formation sur les biais inconscients',
#               'Équipe dédiée à la Diversité & inclusivité',
#               'RTT / Jour de repos',
#               'Participation',
#               'Plan d’épargne entreprise (PEE)',
#               'Prime de cooptation',
#               'Subvention télétravail',
#               'Subventions CSE (Sport, Culture,...)',
#               'Chèques cadeaux',
#               'Chèques vacances',
#               'Team building',
#               "Afterworks, Déjeuners d'équipe, etc.",
#               'Bénévolat',
#               'Partenariat avec des associations',
#               'Plan de développement professionnel',
#               'Financement des certifications',
#               'Mentorat',
#               'Coaching',
#               'VAE : validation des acquis en entreprise',
#               'Prime de naissance',
#               'Journées famille en entreprise',
#               'Congés pour enfant malade',
#               'Ressources pour le soutien familial',
#               'Dispositif de soutien à la parentalité',
#               'Solution de prévention santé mentale',
#               'Salle de sport dans les locaux',
#               'Plan d’épargne pour la retraite collectif (PERCO)',
#               'Parking à vélo',
#               'Parking',
#               'Forfait mobilité durable'],
#  'contract_duration_maximum': None,
#  'contract_duration_minimum': None,
#  'contract_type': 'apprenticeship',
#  'education_level': 'bac_3',
#  'experience_level_minimum': 0,
#  'has_benefits': True,
#  'has_contract_duration': False,
#  'has_education_level': True,
#  'has_experience_level_minimum': True,
#  'has_remote': True,
#  'has_salary_yearly_minimum': False,
#  'is_boosted': False,
#  'key_missions': ['Développer et maintenir des pipelines de données, concevoir '
#                   'et implémenter des modèles de données.',
#                   'Élaborer un système de lineage des modèles DBT, mettre en '
#                   'place un système de traçabilité des données.',
#                   "Contribuer à la création d'un socle de données optimal, "
#                   "participer à l'identification des besoins en données."],
#  'language': 'fr',
#  'name': '[Alternance] Analytics Engineer F/H',
#  'new_profession': {'category_name': 'Technologie et ingénierie',
#                     'category_reference': 'tech-engineering-3NjUy',
#                     'pivot_name': 'Ingénieur de données',
#                     'pivot_reference': 'data-engineer-wOTA3',
#                     'sub_category_name': 'Données/Business Intelligence',
#                     'sub_category_reference': 'data-business-intelligence-yZjY1'},
#  'objectID': '41056f0f-696a-4242-b70e-c0b6a5e6a11a',
#  'offices': [{'city': 'Charenton-le-Pont',
#               'country': 'France',
#               'country_code': 'FR',
#               'district': 'Val-de-Marne',
#               'local_city': 'Charenton-le-Pont',
#               'local_district': 'Val-de-Marne',
#               'local_state': 'Île-de-France',
#               'state': 'Ile-de-France'}],
#  'organization': {'commitments': [],
#                   'cover_image': {'large': {'url': 'https://cdn-images.welcometothejungle.com/faI_vhBGKCADFpl3sEUtF1acz20uswGDs0mvIJOvh6M/rs:auto:1500::/q:85/czM6Ly93dHRqLXByb2R1Y3Rpb24vdXBsb2Fkcy93ZWJzaXRlX29yZ2FuaXphdGlvbi9jb3Zlcl9pbWFnZS93dHRqX2ZyL2ZyLTFlMDk2YzE2LWIyOTEtNDcwOC1iNWY2LTI2Y2JiMTZmNGVkZi5qcGc'},
#                                   'medium': {'url': 'https://cdn-images.welcometothejungle.com/gJ01ktpFPUmCxURoRQJz_cWSOyfDoYFzGRIzJ9okaaU/rs:auto:900::/q:85/czM6Ly93dHRqLXByb2R1Y3Rpb24vdXBsb2Fkcy93ZWJzaXRlX29yZ2FuaXphdGlvbi9jb3Zlcl9pbWFnZS93dHRqX2ZyL2ZyLTFlMDk2YzE2LWIyOTEtNDcwOC1iNWY2LTI2Y2JiMTZmNGVkZi5qcGc'},
#                                   'small': {'url': 'https://cdn-images.welcometothejungle.com/qUR_Zqx03Bt8XaUSumcUrSj5HkXJcQhWFACe8jR8Ldk/rs:auto:640::/q:85/czM6Ly93dHRqLXByb2R1Y3Rpb24vdXBsb2Fkcy93ZWJzaXRlX29yZ2FuaXphdGlvbi9jb3Zlcl9pbWFnZS93dHRqX2ZyL2ZyLTFlMDk2YzE2LWIyOTEtNDcwOC1iNWY2LTI2Y2JiMTZmNGVkZi5qcGc'},
#                                   'social': {'url': 'https://cdn-images.welcometothejungle.com/8jtinUFBdlUERpS7NIi_t9qorjXAtBspr-RQHtwfo20/rs:auto:1200:627:/q:85/czM6Ly93dHRqLXByb2R1Y3Rpb24vdXBsb2Fkcy93ZWJzaXRlX29yZ2FuaXphdGlvbi9jb3Zlcl9pbWFnZS93dHRqX2ZyL2ZyLTFlMDk2YzE2LWIyOTEtNDcwOC1iNWY2LTI2Y2JiMTZmNGVkZi5qcGc'},
#                                   'url': 'https://cdn-images.welcometothejungle.com/s4TTIysRbST2cH1P0dnfQ9cWk4Vuqv6PJZqVz6EqICw/rs:auto:2000:450:/g:fp:0:0.5/q:85/czM6Ly93dHRqLXByb2R1Y3Rpb24vdXBsb2Fkcy93ZWJzaXRlX29yZ2FuaXphdGlvbi9jb3Zlcl9pbWFnZS93dHRqX2ZyL2ZyLTFlMDk2YzE2LWIyOTEtNDcwOC1iNWY2LTI2Y2JiMTZmNGVkZi5qcGc'},
#                   'creation_year': 2014,
#                   'description': None,
#                   'equality_index': 94,
#                   'labels': [],
#                   'logo': {'thumb': {'url': 'https://cdn-images.welcometothejungle.com/xcwtpNX7ZNpOxWzCFeR-MgAoN6mZqGC7NjAMpyM7Yu0/rs:auto:70::/q:85/czM6Ly93dHRqLXByb2R1Y3Rpb24vdXBsb2Fkcy9vcmdhbml6YXRpb24vbG9nby8zNDQ2LzE1NDM0OS9iNjVkNjYyYy00MzVlLTQ3NTItYmIwNi02MmQ2MWUyYmI1MjQucG5n'},
#                            'url': 'https://cdn-images.welcometothejungle.com/ipLXsZpRVUQufzKCSpiVAIps8frElguo1dLNNIbwB5g/rs:auto:400::/q:85/czM6Ly93dHRqLXByb2R1Y3Rpb24vdXBsb2Fkcy9vcmdhbml6YXRpb24vbG9nby8zNDQ2LzE1NDM0OS9iNjVkNjYyYy00MzVlLTQ3NTItYmIwNi02MmQ2MWUyYmI1MjQucG5n'},
#                   'name': 'Nickel',
#                   'nb_employees': 850,
#                   'profile_ranking': 100,
#                   'profile_type': 'standard',
#                   'reference': 'Rl1DYOw',
#                   'slug': 'nickel',
#                   'summary': 'Compte courant sans découvert ouvert en 5 '
#                              'minutes chez un buraliste.'},
#  'organization_score': 80,
#  'profile': '<p>🏅 A propos de vous</p>\r\n'
#             '<ul>\r\n'
#             "<li> Vous êtes étudiant de niveau Bac+4 ou Bac+5 au sein d'une "
#             "École d'Ingénieurs / École de Commerce / Université avec un "
#             'parcours orienté Digital / Data et Business Analytics.</li>\r\n'
#             '<li> Vous souhaitez monter en compétences sur les langages SQL et '
#             'Python.</li>\r\n'
#             '<li> Vous faites preuve de rigueur et adaptabilité.</li>\r\n'
#             "<li> Vous disposez d'un bon esprit d'équipe et d'une "
#             'communication efficace</li>\r\n'
#             "<li> Vous avez un niveau d'anglais opérationnel vous permettant "
#             "d'échanger avec des équipes à l'international</li>\r\n"
#             '</ul>\r\n'
#             '<p><br />🎁 Avantages</p>\r\n'
#             '<ul>\r\n'
#             '<li> Accord de télétravail 🏡</li>\r\n'
#             '<li> Parcours de carrière dynamique</li>\r\n'
#             '<li> 25 jours de congés payés + 5 Nickel days 🌴</li>\r\n'
#             '<li> Epargne salariale : accord de participation et '
#             'abondement</li>\r\n'
#             '<li> La carte ticket restaurant 💳</li>\r\n'
#             '<li> Avantages collaborateurs BNP Paribas : taux et tarifs '
#             'préférentiels</li>\r\n'
#             '<li> Mutuelle avantageuse Henner et prévoyance</li>\r\n'
#             '<li> CSE (Chèques vacances, activités extra-professionnelles, '
#             'etc)</li>\r\n'
#             '<li> Partenariat Gymlib pour les activités sportives et de '
#             'bien-être</li>\r\n'
#             '<li> Localisation proche métro Ligne 8 - Liberté à '
#             'Charenton</li>\r\n'
#             '<li> Pass Mobilité 🚲 500€ par an pour financer vos dépenses en '
#             'lien avec la mobilité durable (sur vos déplacement '
#             'domicile/travail)</li>\r\n'
#             '</ul>\r\n'
#             "<p><br />Le succès de Nickel, c'est la diversité des profils et "
#             'la richesse des parcours de chacun de nos collaborateurs. Plus '
#             "qu'un diplôme, c'est votre personnalité et votre envie de nous "
#             'rejoindre qui fera la différence !</p>',
#  'profile_ranking': 100,
#  'published_at': '2026-03-25T11:07:51Z',
#  'published_at_date': '2026-03-25',
#  'published_at_timestamp': 1774436871,
#  'rank_group_1': 6845,
#  'rank_group_2': 6845,
#  'rank_group_3': 6845,
#  'reference': '41056f0f-696a-4242-b70e-c0b6a5e6a11a',
#  'remote': 'punctual',
#  'salary_currency': 'EUR',
#  'salary_maximum': None,
#  'salary_minimum': None,
#  'salary_period': 'yearly',
#  'salary_yearly_minimum': None,
#  'sectors': [{'name': 'Banque',
#               'parent_name': 'Banques / Assurances / Finance',
#               'parent_reference': 'banking-insurance-finance',
#               'reference': 'banking-1'},
#              {'name': 'FinTech / InsurTech',
#               'parent_name': 'Banques / Assurances / Finance',
#               'parent_reference': 'banking-insurance-finance',
#               'reference': 'fintech-insurtech'}],
#  'slug': 'alternance-analytics-engineer-f-h_charenton-le-pont_NICKE_k80RLow',
#  'source_stage': 'production',
#  'summary': 'Rejoignez Nickel, une entreprise innovante dans le secteur de la '
#             "fintech. En tant qu'Analytics Engineer en alternance, vous "
#             'travaillerez au sein du Pôle Data, où vous contribuerez à '
#             "l'amélioration de la qualité et de la cohérence des données. Vous "
#             'développerez et maintiendrez des pipelines de données, élaborerez '
#             'un système de traçabilité des modèles et contribuerez à la '
#             "création d'un socle de données optimal. Vous bénéficierez d'un "
#             'environnement de travail dynamique avec de nombreux avantages.',
#  'wk_reference': 'NICKE_k80RLow'}
# FIN
